# %%
#%pip install gym[box2d]

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)
        
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

# %%
callback = TrainAndLoggingCallback(200000, os.path.join('Training', 'Models'))

# %%
env = gym.make('CarRacing-v0')
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
#model = PPO.load('./Training/Models/PPO_500k_CarRacing.zip', env)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=10000000, callback=callback)
# Out:
# Track generation: 1210..1515 -> 305-tiles track
# Logging to Training\Logs\PPO_4
# Track generation: 1214..1521 -> 307-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 155  |
# |    iterations      | 1    |
# |    time_elapsed    | 13   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1306..1637 -> 331-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 2            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0065173777 |
# |    clip_fraction        | 0.0843       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.27        |
# |    explained_variance   | 0.00726      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.128        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00677     |
# |    std                  | 1.01         |
# |    value_loss           | 0.59         |
# ------------------------------------------
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 130        |
# |    iterations           | 3          |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00642326 |
# |    clip_fraction        | 0.102      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.27      |
# |    explained_variance   | 0.0909     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0638     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00707   |
# |    std                  | 1          |
# |    value_loss           | 0.482      |
# ----------------------------------------
# Track generation: 1172..1469 -> 297-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 127        |
# |    iterations           | 4          |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01020233 |
# |    clip_fraction        | 0.132      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.105      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0969     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0111    |
# |    std                  | 0.996      |
# |    value_loss           | 0.505      |
# ----------------------------------------
# Track generation: 1067..1338 -> 271-tiles track
# Track generation: 1226..1537 -> 311-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 126         |
# |    iterations           | 5           |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010628108 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.07        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.985       |
# |    value_loss           | 0.422       |
# -----------------------------------------
# Track generation: 1145..1436 -> 291-tiles track
# Track generation: 1284..1609 -> 325-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 6           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014133866 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.114       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0214     |
# |    std                  | 0.975       |
# |    value_loss           | 0.465       |
# -----------------------------------------
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1129..1415 -> 286-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 124         |
# |    iterations           | 7           |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020309957 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.179       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0116     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.958       |
# |    value_loss           | 0.401       |
# -----------------------------------------
# Track generation: 1154..1447 -> 293-tiles track
# Track generation: 1276..1600 -> 324-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 8           |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.023258768 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0391      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0306     |
# |    std                  | 0.941       |
# |    value_loss           | 0.375       |
# -----------------------------------------
# Track generation: 1055..1329 -> 274-tiles track
# Track generation: 1301..1630 -> 329-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 123         |
# |    iterations           | 9           |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.026091374 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0316      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.927       |
# |    value_loss           | 0.381       |
# -----------------------------------------
# Track generation: 1150..1443 -> 293-tiles track
# Track generation: 1185..1486 -> 301-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 122         |
# |    iterations           | 10          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.023789624 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.0897      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0752      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0339     |
# |    std                  | 0.919       |
# |    value_loss           | 0.512       |
# -----------------------------------------
# Track generation: 1084..1359 -> 275-tiles track
# Track generation: 1181..1481 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 122        |
# |    iterations           | 11         |
# |    time_elapsed         | 184        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03105927 |
# |    clip_fraction        | 0.257      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.98      |
# |    explained_variance   | 0.376      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0178     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0404    |
# |    std                  | 0.904      |
# |    value_loss           | 0.299      |
# ----------------------------------------
# Track generation: 1160..1454 -> 294-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 121       |
# |    iterations           | 12        |
# |    time_elapsed         | 201       |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0387401 |
# |    clip_fraction        | 0.322     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.92     |
# |    explained_variance   | 0.501     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00695  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -0.0458   |
# |    std                  | 0.885     |
# |    value_loss           | 0.272     |
# ---------------------------------------
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1061..1330 -> 269-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 13         |
# |    time_elapsed         | 218        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.04085069 |
# |    clip_fraction        | 0.305      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.86      |
# |    explained_variance   | 0.506      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0308    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0453    |
# |    std                  | 0.868      |
# |    value_loss           | 0.206      |
# ----------------------------------------
# Track generation: 1213..1529 -> 316-tiles track
# Track generation: 1205..1511 -> 306-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 14          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.048777826 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0506     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0505     |
# |    std                  | 0.855       |
# |    value_loss           | 0.241       |
# -----------------------------------------
# Track generation: 1102..1389 -> 287-tiles track
# Track generation: 1240..1554 -> 314-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 121        |
# |    iterations           | 15         |
# |    time_elapsed         | 253        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.03895341 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.77      |
# |    explained_variance   | 0.726      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00483   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0444    |
# |    std                  | 0.846      |
# |    value_loss           | 0.257      |
# ----------------------------------------
# Track generation: 1121..1405 -> 284-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 16          |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.037822165 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.208       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.02        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.036      |
# |    std                  | 0.836       |
# |    value_loss           | 0.593       |
# -----------------------------------------
# Track generation: 1209..1515 -> 306-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 17          |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.063797064 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0466     |
# |    std                  | 0.832       |
# |    value_loss           | 0.299       |
# -----------------------------------------
# Track generation: 1035..1298 -> 263-tiles track
# Track generation: 1142..1438 -> 296-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 121         |
# |    iterations           | 18          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.055889636 |
# |    clip_fraction        | 0.358       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.72        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0109      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0434     |
# |    std                  | 0.817       |
# |    value_loss           | 0.553       |
# -----------------------------------------
# Track generation: 1231..1543 -> 312-tiles track
# Track generation: 1220..1529 -> 309-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 19         |
# |    time_elapsed         | 321        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.06380841 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | 0.762      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00398    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0482    |
# |    std                  | 0.813      |
# |    value_loss           | 0.779      |
# ----------------------------------------
# Track generation: 1112..1394 -> 282-tiles track
# Track generation: 1252..1569 -> 317-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 20          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.048764408 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0221      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0422     |
# |    std                  | 0.803       |
# |    value_loss           | 0.433       |
# -----------------------------------------
# Track generation: 1255..1573 -> 318-tiles track
# Track generation: 1116..1402 -> 286-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1152..1449 -> 297-tiles track
# Track generation: 1108..1389 -> 281-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 21          |
# |    time_elapsed         | 356         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.056475475 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.123       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.03       |
# |    std                  | 0.797       |
# |    value_loss           | 1.23        |
# -----------------------------------------
# Track generation: 1314..1652 -> 338-tiles track
# Track generation: 1218..1533 -> 315-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 22         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.07566285 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.149      |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0374    |
# |    std                  | 0.788      |
# |    value_loss           | 0.636      |
# ----------------------------------------
# Track generation: 1211..1525 -> 314-tiles track
# Track generation: 1016..1274 -> 258-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 23          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.061901107 |
# |    clip_fraction        | 0.4         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.102       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0248     |
# |    std                  | 0.788       |
# |    value_loss           | 0.849       |
# -----------------------------------------
# Track generation: 1081..1359 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1063..1340 -> 277-tiles track
# Track generation: 1084..1359 -> 275-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 24          |
# |    time_elapsed         | 409         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.076196596 |
# |    clip_fraction        | 0.449       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0417     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0338     |
# |    std                  | 0.779       |
# |    value_loss           | 0.571       |
# -----------------------------------------
# Track generation: 1245..1560 -> 315-tiles track
# Track generation: 1047..1313 -> 266-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 25         |
# |    time_elapsed         | 426        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.05917096 |
# |    clip_fraction        | 0.396      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0.972      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.127      |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0376    |
# |    std                  | 0.772      |
# |    value_loss           | 0.509      |
# ----------------------------------------
# Track generation: 1170..1467 -> 297-tiles track
# Track generation: 1201..1513 -> 312-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 26         |
# |    time_elapsed         | 444        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.05574297 |
# |    clip_fraction        | 0.384      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.46      |
# |    explained_variance   | 0.936      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.241      |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0268    |
# |    std                  | 0.766      |
# |    value_loss           | 1.08       |
# ----------------------------------------
# Track generation: 1024..1291 -> 267-tiles track
# Track generation: 948..1194 -> 246-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 27          |
# |    time_elapsed         | 461         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.059935257 |
# |    clip_fraction        | 0.428       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.966       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.208       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.764       |
# |    value_loss           | 0.79        |
# -----------------------------------------
# Track generation: 1086..1362 -> 276-tiles track
# Track generation: 1117..1410 -> 293-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 28         |
# |    time_elapsed         | 478        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.06689173 |
# |    clip_fraction        | 0.403      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.44      |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.113      |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.025     |
# |    std                  | 0.762      |
# |    value_loss           | 1.36       |
# ----------------------------------------
# Track generation: 1317..1650 -> 333-tiles track
# Track generation: 1367..1713 -> 346-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 29         |
# |    time_elapsed         | 496        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.06937812 |
# |    clip_fraction        | 0.397      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.42      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0717     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0259    |
# |    std                  | 0.753      |
# |    value_loss           | 0.71       |
# ----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1108..1398 -> 290-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 30          |
# |    time_elapsed         | 513         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.053287655 |
# |    clip_fraction        | 0.425       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.39       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.251       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.753       |
# |    value_loss           | 1.79        |
# -----------------------------------------
# Track generation: 1088..1368 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1042..1314 -> 272-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 31         |
# |    time_elapsed         | 530        |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.09276234 |
# |    clip_fraction        | 0.469      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.38      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0173     |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.0275    |
# |    std                  | 0.743      |
# |    value_loss           | 0.429      |
# ----------------------------------------
# Track generation: 1070..1347 -> 277-tiles track
# Track generation: 993..1251 -> 258-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 32         |
# |    time_elapsed         | 547        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.06481558 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.33      |
# |    explained_variance   | 0.977      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0305    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0394    |
# |    std                  | 0.729      |
# |    value_loss           | 0.381      |
# ----------------------------------------
# Track generation: 1151..1445 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1087..1363 -> 276-tiles track
# Track generation: 1140..1428 -> 288-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 33         |
# |    time_elapsed         | 564        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.07030989 |
# |    clip_fraction        | 0.426      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.29      |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0565     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.025     |
# |    std                  | 0.726      |
# |    value_loss           | 0.381      |
# ----------------------------------------
# Track generation: 1332..1669 -> 337-tiles track
# Track generation: 1207..1513 -> 306-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 34         |
# |    time_elapsed         | 582        |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.14695036 |
# |    clip_fraction        | 0.415      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.3       |
# |    explained_variance   | 0.987      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0318     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0277    |
# |    std                  | 0.728      |
# |    value_loss           | 0.238      |
# ----------------------------------------
# Track generation: 1075..1348 -> 273-tiles track
# Track generation: 1107..1388 -> 281-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 35          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.055778313 |
# |    clip_fraction        | 0.386       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.975       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0287      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0347     |
# |    std                  | 0.719       |
# |    value_loss           | 0.647       |
# -----------------------------------------
# Track generation: 1218..1530 -> 312-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1167..1463 -> 296-tiles track
# Track generation: 1227..1537 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 36         |
# |    time_elapsed         | 616        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.07609393 |
# |    clip_fraction        | 0.356      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0924     |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0305    |
# |    std                  | 0.711      |
# |    value_loss           | 0.332      |
# ----------------------------------------
# Track generation: 1179..1484 -> 305-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 37         |
# |    time_elapsed         | 634        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.05330199 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.919      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.206      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0172    |
# |    std                  | 0.708      |
# |    value_loss           | 2.53       |
# ----------------------------------------
# Track generation: 1163..1460 -> 297-tiles track
# Track generation: 1220..1529 -> 309-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 38         |
# |    time_elapsed         | 651        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.08752988 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.2       |
# |    explained_variance   | 0.982      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00119   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0219    |
# |    std                  | 0.705      |
# |    value_loss           | 0.393      |
# ----------------------------------------
# Track generation: 1180..1479 -> 299-tiles track
# Track generation: 1266..1586 -> 320-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 39         |
# |    time_elapsed         | 669        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.12652554 |
# |    clip_fraction        | 0.438      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.18      |
# |    explained_variance   | 0.974      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0458    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0406    |
# |    std                  | 0.694      |
# |    value_loss           | 0.26       |
# ----------------------------------------
# Track generation: 1039..1303 -> 264-tiles track
# Track generation: 1231..1543 -> 312-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 119       |
# |    iterations           | 40        |
# |    time_elapsed         | 686       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0521485 |
# |    clip_fraction        | 0.379     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.14     |
# |    explained_variance   | 0.938     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.378     |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -0.0217   |
# |    std                  | 0.692     |
# |    value_loss           | 3.33      |
# ---------------------------------------
# Track generation: 1060..1329 -> 269-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 41          |
# |    time_elapsed         | 703         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.056542493 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.752       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00529    |
# |    std                  | 0.691       |
# |    value_loss           | 5.15        |
# -----------------------------------------
# Track generation: 1199..1512 -> 313-tiles track
# Track generation: 1062..1339 -> 277-tiles track
# Track generation: 1070..1349 -> 279-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 42          |
# |    time_elapsed         | 720         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.047509875 |
# |    clip_fraction        | 0.436       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00476    |
# |    std                  | 0.69        |
# |    value_loss           | 8.52        |
# -----------------------------------------
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1159..1458 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 43         |
# |    time_elapsed         | 738        |
# |    total_timesteps      | 88064      |
# | train/                  |            |
# |    approx_kl            | 0.10329783 |
# |    clip_fraction        | 0.419      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.12      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.345      |
# |    n_updates            | 420        |
# |    policy_gradient_loss | -0.012     |
# |    std                  | 0.689      |
# |    value_loss           | 5.14       |
# ----------------------------------------
# Track generation: 1153..1445 -> 292-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 44         |
# |    time_elapsed         | 755        |
# |    total_timesteps      | 90112      |
# | train/                  |            |
# |    approx_kl            | 0.07023299 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.383      |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0188    |
# |    std                  | 0.684      |
# |    value_loss           | 3.16       |
# ----------------------------------------
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 45         |
# |    time_elapsed         | 772        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.07058986 |
# |    clip_fraction        | 0.454      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.93       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.759      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0102    |
# |    std                  | 0.68       |
# |    value_loss           | 4.73       |
# ----------------------------------------
# Track generation: 1252..1568 -> 316-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 46         |
# |    time_elapsed         | 790        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.06224903 |
# |    clip_fraction        | 0.432      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.501      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.00448   |
# |    std                  | 0.679      |
# |    value_loss           | 4.23       |
# ----------------------------------------
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 47         |
# |    time_elapsed         | 807        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.07496032 |
# |    clip_fraction        | 0.474      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.732      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.78       |
# |    n_updates            | 460        |
# |    policy_gradient_loss | 0.00399    |
# |    std                  | 0.682      |
# |    value_loss           | 7.03       |
# ----------------------------------------
# Track generation: 1001..1262 -> 261-tiles track
# Track generation: 1033..1299 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1244..1559 -> 315-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 48          |
# |    time_elapsed         | 825         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.086919785 |
# |    clip_fraction        | 0.438       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.963       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.02        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0045     |
# |    std                  | 0.682       |
# |    value_loss           | 4.12        |
# -----------------------------------------
# Track generation: 1205..1511 -> 306-tiles track
# Track generation: 1114..1404 -> 290-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 49         |
# |    time_elapsed         | 842        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.15671594 |
# |    clip_fraction        | 0.504      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.08      |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.497      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | 0.00913    |
# |    std                  | 0.68       |
# |    value_loss           | 5.02       |
# ----------------------------------------
# Track generation: 1166..1466 -> 300-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 50          |
# |    time_elapsed         | 860         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.096703306 |
# |    clip_fraction        | 0.498       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.954       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00724     |
# |    std                  | 0.679       |
# |    value_loss           | 6.51        |
# -----------------------------------------
# Track generation: 1243..1558 -> 315-tiles track
# Track generation: 1083..1358 -> 275-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 119        |
# |    iterations           | 51         |
# |    time_elapsed         | 877        |
# |    total_timesteps      | 104448     |
# | train/                  |            |
# |    approx_kl            | 0.10172427 |
# |    clip_fraction        | 0.462      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.06      |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.256      |
# |    n_updates            | 500        |
# |    policy_gradient_loss | 0.0116     |
# |    std                  | 0.672      |
# |    value_loss           | 2.72       |
# ----------------------------------------
# Track generation: 1215..1523 -> 308-tiles track
# Track generation: 1313..1645 -> 332-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 52          |
# |    time_elapsed         | 895         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.074300155 |
# |    clip_fraction        | 0.459       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.829       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.000542   |
# |    std                  | 0.668       |
# |    value_loss           | 6.5         |
# -----------------------------------------
# Track generation: 1085..1361 -> 276-tiles track
# Track generation: 1071..1343 -> 272-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 53         |
# |    time_elapsed         | 912        |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.08728915 |
# |    clip_fraction        | 0.498      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.02      |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.848      |
# |    n_updates            | 520        |
# |    policy_gradient_loss | 0.00243    |
# |    std                  | 0.666      |
# |    value_loss           | 5.28       |
# ----------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 1111..1393 -> 282-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 118        |
# |    iterations           | 54         |
# |    time_elapsed         | 930        |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.07538091 |
# |    clip_fraction        | 0.465      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.29       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | 0.00604    |
# |    std                  | 0.661      |
# |    value_loss           | 10.3       |
# ...
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 984        |
# |    time_elapsed         | 17183      |
# |    total_timesteps      | 2015232    |
# | train/                  |            |
# |    approx_kl            | 0.35715404 |
# |    clip_fraction        | 0.58       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.45       |
# |    explained_variance   | 0.912      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00623    |
# |    n_updates            | 9830       |
# |    policy_gradient_loss | 0.0478     |
# |    std                  | 0.0423     |
# |    value_loss           | 0.00799    |
# ----------------------------------------
# Track generation: 1088..1367 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1140..1437 -> 297-tiles track
# Track generation: 1225..1535 -> 310-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 985        |
# |    time_elapsed         | 17200      |
# |    total_timesteps      | 2017280    |
# | train/                  |            |
# |    approx_kl            | 0.49038035 |
# |    clip_fraction        | 0.517      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.41       |
# |    explained_variance   | 0.841      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0767     |
# |    n_updates            | 9840       |
# |    policy_gradient_loss | 0.0421     |
# |    std                  | 0.0426     |
# |    value_loss           | 0.00836    |
# ----------------------------------------
# Track generation: 1091..1374 -> 283-tiles track
# Track generation: 1153..1454 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 986        |
# |    time_elapsed         | 17217      |
# |    total_timesteps      | 2019328    |
# | train/                  |            |
# |    approx_kl            | 0.34934372 |
# |    clip_fraction        | 0.529      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.4        |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0475     |
# |    n_updates            | 9850       |
# |    policy_gradient_loss | 0.0216     |
# |    std                  | 0.0428     |
# |    value_loss           | 0.00686    |
# ----------------------------------------
# Track generation: 1290..1626 -> 336-tiles track
# Track generation: 1075..1356 -> 281-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 987        |
# |    time_elapsed         | 17235      |
# |    total_timesteps      | 2021376    |
# | train/                  |            |
# |    approx_kl            | 0.39802575 |
# |    clip_fraction        | 0.562      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.38       |
# |    explained_variance   | 0.901      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0392    |
# |    n_updates            | 9860       |
# |    policy_gradient_loss | 0.0297     |
# |    std                  | 0.0433     |
# |    value_loss           | 0.00626    |
# ----------------------------------------
# Track generation: 991..1247 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1106..1387 -> 281-tiles track
# Track generation: 1359..1703 -> 344-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 988        |
# |    time_elapsed         | 17252      |
# |    total_timesteps      | 2023424    |
# | train/                  |            |
# |    approx_kl            | 0.16843203 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.34       |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0318    |
# |    n_updates            | 9870       |
# |    policy_gradient_loss | 0.0399     |
# |    std                  | 0.044      |
# |    value_loss           | 0.00837    |
# ----------------------------------------
# Track generation: 1065..1342 -> 277-tiles track
# Track generation: 1283..1608 -> 325-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 989        |
# |    time_elapsed         | 17270      |
# |    total_timesteps      | 2025472    |
# | train/                  |            |
# |    approx_kl            | 0.34561378 |
# |    clip_fraction        | 0.522      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.32       |
# |    explained_variance   | 0.906      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0725     |
# |    n_updates            | 9880       |
# |    policy_gradient_loss | 0.0351     |
# |    std                  | 0.0442     |
# |    value_loss           | 0.00604    |
# ----------------------------------------
# Track generation: 1080..1354 -> 274-tiles track
# Track generation: 1008..1271 -> 263-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 990       |
# |    time_elapsed         | 17290     |
# |    total_timesteps      | 2027520   |
# | train/                  |           |
# |    approx_kl            | 0.3089661 |
# |    clip_fraction        | 0.522     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 5.29      |
# |    explained_variance   | 0.937     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00509   |
# |    n_updates            | 9890      |
# |    policy_gradient_loss | 0.0255    |
# |    std                  | 0.0445    |
# |    value_loss           | 0.00548   |
# ---------------------------------------
# Track generation: 1072..1352 -> 280-tiles track
# Track generation: 980..1235 -> 255-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 991        |
# |    time_elapsed         | 17307      |
# |    total_timesteps      | 2029568    |
# | train/                  |            |
# |    approx_kl            | 0.26068026 |
# |    clip_fraction        | 0.525      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.26       |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0366     |
# |    n_updates            | 9900       |
# |    policy_gradient_loss | 0.0433     |
# |    std                  | 0.0451     |
# |    value_loss           | 0.00564    |
# ----------------------------------------
# Track generation: 1279..1603 -> 324-tiles track
# Track generation: 1200..1506 -> 306-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 117        |
# |    iterations           | 992        |
# |    time_elapsed         | 17326      |
# |    total_timesteps      | 2031616    |
# | train/                  |            |
# |    approx_kl            | 0.14892092 |
# |    clip_fraction        | 0.468      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | 5.24       |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0688     |
# |    n_updates            | 9910       |
# |    policy_gradient_loss | 0.0237     |
# |    std                  | 0.0451     |
# |    value_loss           | 0.00393    |
# ----------------------------------------
# Track generation: 970..1217 -> 247-tiles track
# Track generation: 1059..1337 -> 278-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 117       |
# |    iterations           | 993       |
# |    time_elapsed         | 17345     |
# |    total_timesteps      | 2033664   |
# | train/                  |           |
# |    approx_kl            | 0.2733298 |
# |    clip_fraction        | 0.537     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | 5.22      |
# |    explained_variance   | 0.93      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0266    |
# |    n_updates            | 9920      |
# |    policy_gradient_loss | 0.0296    |
# |    std                  | 0.0455    |
# |    value_loss           | 0.00588   |
# ---------------------------------------
# Track generation: 1215..1521 -> 306-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model.learn(total_timesteps=10000000, callback=callback)
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\ppo\ppo.py:308, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     299 def learn(
#     300     self: SelfPPO,
#     301     total_timesteps: int,
#    (...)
#     306     progress_bar: bool = False,
#     307 ) -> SelfPPO:
# --> 308     return super().learn(
#     309         total_timesteps=total_timesteps,
#     310         callback=callback,
#     311         log_interval=log_interval,
#     312         tb_log_name=tb_log_name,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314         progress_bar=progress_bar,
#     315     )
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     247 callback.on_training_start(locals(), globals())
#     249 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\policies.py:614, in ActorCriticPolicy.forward(self, obs, deterministic)
#     606 """
#     607 Forward pass in all the networks (actor and critic)
#     608
#    (...)
#     611 :return: action, value and log probability of the action
#     612 """
#     613 # Preprocess the observation if needed
# --> 614 features = self.extract_features(obs)
#     615 if self.share_features_extractor:
#     616     latent_pi, latent_vf = self.mlp_extractor(features)
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\policies.py:637, in ActorCriticPolicy.extract_features(self, obs)
#     630 """
#     631 Preprocess the observation if needed and extract features.
#     632
#     633 :param obs: Observation
#     634 :return: the output of the features extractor(s)
#     635 """
#     636 if self.share_features_extractor:
# --> 637     return super().extract_features(obs, self.features_extractor)
#     638 else:
#     639     pi_features = super().extract_features(obs, self.pi_features_extractor)
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\policies.py:130, in BaseModel.extract_features(self, obs, features_extractor)
#     122 """
#     123 Preprocess the observation if needed and extract features.
#     124
#    (...)
#     127  :return: The extracted features
#     128 """
#     129 preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 130 return features_extractor(preprocessed_obs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\damem\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\torch_layers.py:102, in NatureCNN.forward(self, observations)
#     101 def forward(self, observations: th.Tensor) -> th.Tensor:
# --> 102     return self.linear(self.cnn(observations))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\AppData\Roaming\Python\Python310\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
loaded_model = PPO.load('./Training/Models/best_model_400000.zip')

# %%
evaluate_policy(loaded_model,env, render=True, n_eval_episodes=1)
env.close()
# Out:
# Track generation: 1184..1484 -> 300-tiles track
# Track generation: 1131..1418 -> 287-tiles track

# %%
for n in range(1, 6):
    obs = env.reset()
    score = 0
    done = False
    while not done:
        env.render()
        action = model.predict(obs.copy())
        obs, reward, done, info = env.step(action[0])
        score+=reward
    print(f"episode - {n} || score - {score}")
env.close()
# Out:
# Track generation: 976..1227 -> 251-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1121..1411 -> 290-tiles track
# episode - 1 || score - 412.1107266435878
# Track generation: 1020..1279 -> 259-tiles track
# episode - 2 || score - 551.1627906976701
# Track generation: 1167..1472 -> 305-tiles track
# episode - 3 || score - 54.60526315789862
# Track generation: 939..1184 -> 245-tiles track
# episode - 4 || score - 354.9180327868705
# Track generation: 1147..1438 -> 291-tiles track
# episode - 5 || score - 462.0689655172273
