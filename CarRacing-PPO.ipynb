# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
env = gym.make('CarRacing-v0')
env = DummyVecEnv([lambda: env])

# %%
log_path = os.path.join('Training', 'Logs')
model = PPO('CnnPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Track generation: 1057..1330 -> 273-tiles track
# Logging to Training\Logs\PPO_1
# Track generation: 977..1231 -> 254-tiles track
# Track generation: 1191..1493 -> 302-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -50.5    |
# | time/              |          |
# |    fps             | 124      |
# |    iterations      | 1        |
# |    time_elapsed    | 16       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1095..1382 -> 287-tiles track
# Track generation: 1195..1508 -> 313-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -52.3        |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 2            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0075847837 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00343      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.408        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00665     |
# |    std                  | 0.997        |
# |    value_loss           | 0.946        |
# ------------------------------------------
# Track generation: 1087..1373 -> 286-tiles track
# Track generation: 1217..1534 -> 317-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.8       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 3           |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009097771 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.0521      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.348       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00949    |
# |    std                  | 0.996       |
# |    value_loss           | 0.582       |
# -----------------------------------------
# Track generation: 1102..1386 -> 284-tiles track
# Track generation: 1136..1429 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.4       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 4           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008110248 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.116       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.269       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00607    |
# |    std                  | 0.985       |
# |    value_loss           | 0.67        |
# -----------------------------------------
# Track generation: 999..1258 -> 259-tiles track
# Track generation: 1275..1598 -> 323-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.3       |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 5           |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009026005 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.0715      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 0.977       |
# |    value_loss           | 0.446       |
# -----------------------------------------
# Track generation: 1071..1345 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1086..1362 -> 276-tiles track
# Track generation: 1023..1290 -> 267-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 6           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012000153 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.971       |
# |    value_loss           | 0.578       |
# -----------------------------------------
# Track generation: 1131..1418 -> 287-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49         |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 7           |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016475225 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | -0.0856     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00384     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.967       |
# |    value_loss           | 0.281       |
# -----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1196..1509 -> 313-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.3       |
# | time/                   |             |
# |    fps                  | 117         |
# |    iterations           | 8           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015341686 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0113      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.952       |
# |    value_loss           | 0.308       |
# -----------------------------------------
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 1020..1284 -> 264-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 9           |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012757189 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0205      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.022      |
# |    std                  | 0.948       |
# |    value_loss           | 0.232       |
# -----------------------------------------
# Track generation: 1190..1492 -> 302-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 10          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.021896359 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.012       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.935       |
# |    value_loss           | 0.231       |
# -----------------------------------------
# Track generation: 1151..1443 -> 292-tiles track
# Track generation: 1152..1444 -> 292-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.1       |
# | time/                   |             |
# |    fps                  | 118         |
# |    iterations           | 11          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014973452 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00236     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.921       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# Track generation: 1162..1463 -> 301-tiles track
# Track generation: 1320..1654 -> 334-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52         |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 12          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.021527901 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.909       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# Track generation: 1195..1504 -> 309-tiles track
# Track generation: 978..1234 -> 256-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 13          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021691605 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00212     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0251     |
# |    std                  | 0.891       |
# |    value_loss           | 0.177       |
# -----------------------------------------
# Track generation: 1260..1580 -> 320-tiles track
# Track generation: 1094..1380 -> 286-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.6       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 14          |
# |    time_elapsed         | 239         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.018225059 |
# |    clip_fraction        | 0.217       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.112       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0223     |
# |    std                  | 0.885       |
# |    value_loss           | 0.4         |
# -----------------------------------------
# Track generation: 1026..1295 -> 269-tiles track
# Track generation: 1273..1595 -> 322-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.7       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 15          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023769509 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000714   |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.876       |
# |    value_loss           | 0.41        |
# -----------------------------------------
# Track generation: 1165..1461 -> 296-tiles track
# Track generation: 1270..1601 -> 331-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.8       |
# | time/                   |             |
# |    fps                  | 119         |
# |    iterations           | 16          |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.027918745 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00695     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.864       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# Track generation: 1136..1432 -> 296-tiles track
# Track generation: 1208..1513 -> 305-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -43.1      |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 17         |
# |    time_elapsed         | 289        |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.02733042 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.8       |
# |    explained_variance   | 0.946      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00214    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0315    |
# |    std                  | 0.855      |
# |    value_loss           | 0.258      |
# ----------------------------------------
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1198..1501 -> 303-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -42.3      |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 18         |
# |    time_elapsed         | 306        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03582517 |
# |    clip_fraction        | 0.292      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.76      |
# |    explained_variance   | 0.948      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00842   |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0325    |
# |    std                  | 0.843      |
# |    value_loss           | 0.232      |
# ----------------------------------------
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1220..1529 -> 309-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -40        |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 19         |
# |    time_elapsed         | 323        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.04087749 |
# |    clip_fraction        | 0.286      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.72      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0258     |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0332    |
# |    std                  | 0.829      |
# |    value_loss           | 0.219      |
# ----------------------------------------
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1104..1384 -> 280-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -37.9       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 20          |
# |    time_elapsed         | 341         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.029535756 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00619    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0386     |
# |    std                  | 0.819       |
# |    value_loss           | 0.247       |
# -----------------------------------------
# Track generation: 1042..1307 -> 265-tiles track
# Track generation: 1027..1288 -> 261-tiles track
# Track generation: 1011..1269 -> 258-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -33.1       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 21          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.034621444 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.62       |
# |    explained_variance   | 0.839       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0616      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0328     |
# |    std                  | 0.804       |
# |    value_loss           | 0.797       |
# -----------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1158..1452 -> 294-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -31.6      |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 22         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.04089077 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00704    |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0346    |
# |    std                  | 0.787      |
# |    value_loss           | 0.393      |
# ----------------------------------------
# Track generation: 1147..1441 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1037..1309 -> 272-tiles track
# Track generation: 1163..1460 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -28.3       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 23          |
# |    time_elapsed         | 391         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.037893824 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0104     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0332     |
# |    std                  | 0.78        |
# |    value_loss           | 0.619       |
# -----------------------------------------
# Track generation: 1091..1368 -> 277-tiles track
# Track generation: 998..1258 -> 260-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -27.8      |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 24         |
# |    time_elapsed         | 408        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.05070685 |
# |    clip_fraction        | 0.369      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0.907      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0637     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0394    |
# |    std                  | 0.773      |
# |    value_loss           | 0.723      |
# ----------------------------------------
# Track generation: 1093..1370 -> 277-tiles track
# Track generation: 1204..1509 -> 305-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -24.5     |
# | time/                   |           |
# |    fps                  | 120       |
# |    iterations           | 25        |
# |    time_elapsed         | 424       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0712896 |
# |    clip_fraction        | 0.344     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.46     |
# |    explained_variance   | 0.972     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0101    |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -0.0417   |
# |    std                  | 0.763     |
# |    value_loss           | 0.301     |
# ---------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -22         |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 26          |
# |    time_elapsed         | 442         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.041713014 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.42       |
# |    explained_variance   | 0.888       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0854      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0384     |
# |    std                  | 0.755       |
# |    value_loss           | 0.67        |
# -----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1051..1321 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1119..1403 -> 284-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -17.3       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 27          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.053702626 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -3.46e-05   |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0456     |
# |    std                  | 0.742       |
# |    value_loss           | 0.63        |
# -----------------------------------------
# Track generation: 1219..1528 -> 309-tiles track
# Track generation: 1100..1379 -> 279-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 28          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.044826068 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.34       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.124       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0331     |
# |    std                  | 0.736       |
# |    value_loss           | 1.12        |
# -----------------------------------------
# Track generation: 1419..1778 -> 359-tiles track
# Track generation: 1068..1346 -> 278-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -8.14       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 29          |
# |    time_elapsed         | 492         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.060646355 |
# |    clip_fraction        | 0.388       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0404      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0415     |
# |    std                  | 0.73        |
# |    value_loss           | 0.756       |
# -----------------------------------------
# Track generation: 1008..1272 -> 264-tiles track
# Track generation: 934..1178 -> 244-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -1.02       |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 30          |
# |    time_elapsed         | 509         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.054152813 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.29       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.201       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0294     |
# |    std                  | 0.723       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# Track generation: 1089..1365 -> 276-tiles track
# Track generation: 1057..1331 -> 274-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.14        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 31          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.055427406 |
# |    clip_fraction        | 0.367       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.26       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.717       |
# |    value_loss           | 1.49        |
# -----------------------------------------
# Track generation: 1319..1653 -> 334-tiles track
# Track generation: 1232..1544 -> 312-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 4.41        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 32          |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.059817277 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.078       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0285     |
# |    std                  | 0.71        |
# |    value_loss           | 1.2         |
# -----------------------------------------
# Track generation: 1055..1323 -> 268-tiles track
# Track generation: 1264..1584 -> 320-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 8.92        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 33          |
# |    time_elapsed         | 561         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.053123783 |
# |    clip_fraction        | 0.414       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.19       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.09        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.701       |
# |    value_loss           | 0.574       |
# -----------------------------------------
# Track generation: 1309..1648 -> 339-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 11.8      |
# | time/                   |           |
# |    fps                  | 120       |
# |    iterations           | 34        |
# |    time_elapsed         | 578       |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0452557 |
# |    clip_fraction        | 0.344     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.15     |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.246     |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -0.03     |
# |    std                  | 0.691     |
# |    value_loss           | 1.23      |
# ---------------------------------------
# Track generation: 1114..1396 -> 282-tiles track
# Track generation: 1264..1595 -> 331-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 16.5       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 35         |
# |    time_elapsed         | 595        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.06647455 |
# |    clip_fraction        | 0.391      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.11      |
# |    explained_variance   | 0.943      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.141      |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0301    |
# |    std                  | 0.683      |
# |    value_loss           | 0.909      |
# ----------------------------------------
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1200..1504 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 20.4        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 36          |
# |    time_elapsed         | 613         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.065552115 |
# |    clip_fraction        | 0.401       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.723       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.153       |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.673       |
# |    value_loss           | 1.16        |
# -----------------------------------------
# Track generation: 1175..1473 -> 298-tiles track
# Track generation: 1044..1309 -> 265-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 26.3        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 37          |
# |    time_elapsed         | 629         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.051335167 |
# |    clip_fraction        | 0.399       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.125       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0292     |
# |    std                  | 0.663       |
# |    value_loss           | 1.13        |
# -----------------------------------------
# Track generation: 1128..1421 -> 293-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 33.6       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 38         |
# |    time_elapsed         | 646        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.06843197 |
# |    clip_fraction        | 0.439      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.98      |
# |    explained_variance   | 0.754      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.357      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0251    |
# |    std                  | 0.657      |
# |    value_loss           | 1.44       |
# ----------------------------------------
# Track generation: 1287..1613 -> 326-tiles track
# Track generation: 1137..1428 -> 291-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1016..1274 -> 258-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 38.3       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 39         |
# |    time_elapsed         | 663        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.05459542 |
# |    clip_fraction        | 0.42       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.95      |
# |    explained_variance   | 0.803      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.485      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.015     |
# |    std                  | 0.653      |
# |    value_loss           | 1.8        |
# ----------------------------------------
# Track generation: 1247..1570 -> 323-tiles track
# Track generation: 1140..1429 -> 289-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 41.2       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 40         |
# |    time_elapsed         | 681        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.05103755 |
# |    clip_fraction        | 0.387      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.93      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.304      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.025     |
# |    std                  | 0.65       |
# |    value_loss           | 2.14       |
# ----------------------------------------
# Track generation: 1153..1450 -> 297-tiles track
# Track generation: 1228..1539 -> 311-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | 44.4      |
# | time/                   |           |
# |    fps                  | 120       |
# |    iterations           | 41        |
# |    time_elapsed         | 698       |
# |    total_timesteps      | 83968     |
# | train/                  |           |
# |    approx_kl            | 0.0631524 |
# |    clip_fraction        | 0.427     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.92     |
# |    explained_variance   | 0.937     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.103     |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -0.009    |
# |    std                  | 0.647     |
# |    value_loss           | 0.867     |
# ---------------------------------------
# Track generation: 992..1247 -> 255-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1199..1503 -> 304-tiles track
# Track generation: 1193..1455 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1104..1384 -> 280-tiles track
# Track generation: 1179..1478 -> 299-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 48.1        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 42          |
# |    time_elapsed         | 715         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.045468464 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.202       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.642       |
# |    value_loss           | 1.08        |
# -----------------------------------------
# Track generation: 1226..1537 -> 311-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 51.7        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 43          |
# |    time_elapsed         | 732         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.042143036 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.88       |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.355       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.639       |
# |    value_loss           | 1.37        |
# -----------------------------------------
# Track generation: 1200..1510 -> 310-tiles track
# Track generation: 1048..1317 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1084..1359 -> 275-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 53.7        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 44          |
# |    time_elapsed         | 749         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.075340524 |
# |    clip_fraction        | 0.43        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0226      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.633       |
# |    value_loss           | 1.05        |
# -----------------------------------------
# Track generation: 1144..1434 -> 290-tiles track
# Track generation: 1163..1458 -> 295-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 60.6       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 45         |
# |    time_elapsed         | 766        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.08101393 |
# |    clip_fraction        | 0.423      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.82      |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.193      |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0138    |
# |    std                  | 0.627      |
# |    value_loss           | 1.09       |
# ----------------------------------------
# Track generation: 1232..1544 -> 312-tiles track
# Track generation: 1276..1599 -> 323-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | 69.9        |
# | time/                   |             |
# |    fps                  | 120         |
# |    iterations           | 46          |
# |    time_elapsed         | 784         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.053824432 |
# |    clip_fraction        | 0.424       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.407       |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.629       |
# |    value_loss           | 2.9         |
# -----------------------------------------
# Track generation: 1286..1612 -> 326-tiles track
# Track generation: 1017..1275 -> 258-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 74.6       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 47         |
# |    time_elapsed         | 801        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.06878175 |
# |    clip_fraction        | 0.411      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.8       |
# |    explained_variance   | 0.668      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.397      |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0275    |
# |    std                  | 0.625      |
# |    value_loss           | 2.94       |
# ----------------------------------------
# Track generation: 1085..1360 -> 275-tiles track
# Track generation: 982..1238 -> 256-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 79.5       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 48         |
# |    time_elapsed         | 819        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.07803789 |
# |    clip_fraction        | 0.494      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.79      |
# |    explained_variance   | 0.928      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.275      |
# |    n_updates            | 470        |
# |    policy_gradient_loss | 0.00776    |
# |    std                  | 0.624      |
# |    value_loss           | 1.7        |
# ----------------------------------------
# Track generation: 1081..1355 -> 274-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | 82.7       |
# | time/                   |            |
# |    fps                  | 120        |
# |    iterations           | 49         |
# |    time_elapsed         | 836        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.07522136 |
# |    clip_fraction        | 0.458      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.77      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.316      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.00158   |
# |    std                  | 0.621      |
# |    value_loss           | 2.98       |
# ----------------------------------------

# %%
model.save(os.path.join('Training', 'Models', 'PPO_100k_CarRacing'))
# Out:
# c:\Users\damem\AppData\Local\Programs\Python\Python311\Lib\site-packages\stable_baselines3\common\save_util.py:276: UserWarning: Path 'Training\Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
for n in range(1, 6):
    obs = env.reset()
    score = 0
    done = False
    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, info = env.step(action)
        score+=reward
env.close()
# Out:
# Track generation: 1187..1488 -> 301-tiles track
# c:\Users\damem\AppData\Local\Programs\Python\Python311\Lib\site-packages\pyglet\image\codecs\wic.py:406: UserWarning: [WinError -2147417850] Cannot change thread mode after it is set
#   warnings.warn(str(err))
# Track generation: 988..1239 -> 251-tiles track
# Track generation: 1239..1553 -> 314-tiles track
# Track generation: 1292..1626 -> 334-tiles track
# Track generation: 1279..1602 -> 323-tiles track
